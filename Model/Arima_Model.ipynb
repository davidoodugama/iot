# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.1.0-cp39-cp39-win_amd64.whl (3.3 MB)
# Collecting packaging>=20.0
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sbudd\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.0.8-py3-none-any.whl (98 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.2-cp39-cp39-win_amd64.whl (55 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.32.0-py3-none-any.whl (900 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\sbudd\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\sbudd\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, packaging, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.32.0 kiwisolver-1.4.2 matplotlib-3.5.1 packaging-21.3 pillow-9.1.0 pyparsing-3.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df = pd.read_csv('GlobalLandTemperaturesByCity.csv',index_col = "dt", parse_dates = True)

# %%
df.head(10)
# Out:
#             AverageTemperature  AverageTemperatureUncertainty     City  \
# dt
# 1796-01-01              24.317                          2.190  Colombo
# 1796-02-01              23.923                          1.484  Colombo
# 1796-03-01              24.407                          2.309  Colombo
# 1796-04-01              27.171                          1.650  Colombo
# 1796-05-01              29.050                          1.290  Colombo
# 1796-06-01              28.539                          3.125  Colombo
# 1796-07-01              26.857                          2.249  Colombo
# 1796-08-01              26.887                          2.950  Colombo
# 1796-09-01              27.123                          3.379  Colombo
# 1796-10-01              27.562                          1.493  Colombo
#
#               Country
# dt
# 1796-01-01  Sri Lanka
# 1796-02-01  Sri Lanka
# 1796-03-01  Sri Lanka
# 1796-04-01  Sri Lanka
# 1796-05-01  Sri Lanka
# 1796-06-01  Sri Lanka
# 1796-07-01  Sri Lanka
# 1796-08-01  Sri Lanka
# 1796-09-01  Sri Lanka
# 1796-10-01  Sri Lanka

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count         2508.000000                    2508.000000
# mean            26.631452                       0.940125
# std              1.608891                       0.756954
# min             21.010000                       0.134000
# 25%             25.505000                       0.380000
# 50%             26.865500                       0.619500
# 75%             27.772750                       1.388000
# max             30.682000                       5.807000

# %%
df_srilanka = df.drop('AverageTemperatureUncertainty', axis=1)
df_srilanka = df_srilanka.drop('Country',axis=1)

# %%
df_srilanka
# Out:
#             AverageTemperature     City
# dt
# 1796-01-01              24.317  Colombo
# 1796-02-01              23.923  Colombo
# 1796-03-01              24.407  Colombo
# 1796-04-01              27.171  Colombo
# 1796-05-01              29.050  Colombo
# ...                        ...      ...
# 2013-05-01              29.718  Colombo
# 2013-06-01              27.686  Colombo
# 2013-07-01              26.519  Colombo
# 2013-08-01              26.953  Colombo
# 2013-09-01                 NaN  Colombo
#
# [2613 rows x 2 columns]

# %%
df_srilanka = df_srilanka.drop('City',axis=1)

# %%
df_srilanka
# Out:
#             AverageTemperature
# dt
# 1796-01-01              24.317
# 1796-02-01              23.923
# 1796-03-01              24.407
# 1796-04-01              27.171
# 1796-05-01              29.050
# ...                        ...
# 2013-05-01              29.718
# 2013-06-01              27.686
# 2013-07-01              26.519
# 2013-08-01              26.953
# 2013-09-01                 NaN
#
# [2613 rows x 1 columns]

# %%
# Testing whether there are null values
df_srilanka[df_srilanka.isnull()]
# Out:
#             AverageTemperature
# dt
# 1796-01-01                 NaN
# 1796-02-01                 NaN
# 1796-03-01                 NaN
# 1796-04-01                 NaN
# 1796-05-01                 NaN
# ...                        ...
# 2013-05-01                 NaN
# 2013-06-01                 NaN
# 2013-07-01                 NaN
# 2013-08-01                 NaN
# 2013-09-01                 NaN
#
# [2613 rows x 1 columns]

# %%
len(df_srilanka[df_srilanka.isnull()])
# Out:
# 2613

# %%
df_srilanka = df_srilanka.sort_index()

# %%
df_srilanka.index
# Out:
# DatetimeIndex(['1796-01-01', '1796-02-01', '1796-03-01', '1796-04-01',
#                '1796-05-01', '1796-06-01', '1796-07-01', '1796-08-01',
#                '1796-09-01', '1796-10-01',
#                ...
#                '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01',
#                '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01',
#                '2013-08-01', '2013-09-01'],
#               dtype='datetime64[ns]', name='dt', length=2613, freq=None)

# %%
df_srilanka.AverageTemperature.fillna(method='pad', inplace=True)

# %%
df_srilanka[df_srilanka.AverageTemperature.isnull()]
# Out:
# Empty DataFrame
# Columns: [AverageTemperature]
# Index: []

# %%
df_srilanka.describe()
# Out:
#        AverageTemperature
# count          2613.00000
# mean             26.60608
# std               1.59454
# min              21.01000
# 25%              25.48600
# 50%              26.78700
# 75%              27.72500
# max              30.68200

# %%
df_srilanka['Ticks'] = range(0,len(df_srilanka.index.values))

# %%
df_srilanka.head(10)
# Out:
#             AverageTemperature  Ticks
# dt
# 1796-01-01              24.317      0
# 1796-02-01              23.923      1
# 1796-03-01              24.407      2
# 1796-04-01              27.171      3
# 1796-05-01              29.050      4
# 1796-06-01              28.539      5
# 1796-07-01              26.857      6
# 1796-08-01              26.887      7
# 1796-09-01              27.123      8
# 1796-10-01              27.562      9

# %%
df_srilanka.tail(10)
# Out:
#             AverageTemperature  Ticks
# dt
# 2012-12-01              26.828   2603
# 2013-01-01              24.187   2604
# 2013-02-01              25.005   2605
# 2013-03-01              26.301   2606
# 2013-04-01              27.335   2607
# 2013-05-01              29.718   2608
# 2013-06-01              27.686   2609
# 2013-07-01              26.519   2610
# 2013-08-01              26.953   2611
# 2013-09-01              26.953   2612

# %%
fig = plt.figure(1)
ax1 = fig.add_subplot(111)
ax1.set_xlabel('Ticks')
ax1.set_ylabel('Avg. Temp.')
ax1.set_title('Original Plot')
ax1.plot('Ticks', 'AverageTemperature', data = df_srilanka);

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.13.2-cp39-cp39-win_amd64.whl (9.1 MB)
# Collecting patsy>=0.5.2
#   Using cached patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\sbudd\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (1.22.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\sbudd\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (1.4.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\sbudd\appdata\local\programs\python\python39\lib\site-packages (from statsmodels) (21.3)
# Collecting scipy>=1.3
#   Using cached scipy-1.8.0-cp39-cp39-win_amd64.whl (36.9 MB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sbudd\appdata\local\programs\python\python39\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.8)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sbudd\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sbudd\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in c:\users\sbudd\appdata\roaming\python\python39\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-0.5.2 scipy-1.8.0 statsmodels-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.stattools import adfuller
def stationarity_check(ts):
    
    
    # Perform Augmented Dickey-Fuller test:
    print('Augmented Dickey-Fuller test:')
    df_test = adfuller(ts)
    print("type of df_test: ",type(df_test))
    print("df_test: ",df_test)
    df_output = pd.Series(df_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    print("df_output: \n",df_output)
    for key,value in df_test[4].items():
        df_output['Critical Value (%s)'%key] = value
    print(df_output)

# %%
stationarity_check(df_srilanka.AverageTemperature)
# Out:
# Augmented Dickey-Fuller test:
# type of df_test:  <class 'tuple'>
# df_test:  (-4.5504715521571315, 0.00015922403226496356, 27, 2585, {'1%': -3.4328822265006687, '5%': -2.862658740388024, '10%': -2.5673655460943023}, 4861.732645713535)
# df_output:
#  Test Statistic                   -4.550472
# p-value                           0.000159
# #Lags Used                       27.000000
# Number of Observations Used    2585.000000
# dtype: float64
# Test Statistic                   -4.550472
# p-value                           0.000159
# #Lags Used                       27.000000
# Number of Observations Used    2585.000000
# Critical Value (1%)              -3.432882
# Critical Value (5%)              -2.862659
# Critical Value (10%)             -2.567366
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf

# %%
plot_acf(df_srilanka.AverageTemperature, lags=50)
plot_pacf(df_srilanka.AverageTemperature, lags=50)
plt.xlabel('lags')
plt.show()
# Out:
# C:\Users\sbudd\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
import itertools
p = q = r = range(0, 4)
pqr = itertools.product(p, q)
for param in pqr:
    try:
        mod = ARIMA(df_srilanka.AverageTemperature,order=param)
        results = mod.fit()
        print('ARMA{} - AIC:{}'.format(param, results.aic))
    except:
        continue

# %%
model = ARIMA(df_srilanka.AverageTemperature, order=(3,0,3))  
results_MA = model.fit()  
plt.plot(df_srilanka.AverageTemperature)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('Fitting data _ MSE: %.2f'% (((results_MA.fittedvalues-df_srilanka.AverageTemperature)**2).mean()))
plt.show()
# Out:
# C:\Users\sbudd\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\sbudd\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\sbudd\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\sbudd\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
predictions = results_MA.predict('2013-10-01','2014-10-01').rename('Forward Predictions')
predictions2 = results_MA.predict('2012-08-01', '2013-08-01').rename('Backward Predictions')

# %%
predictions
# Out:
# 2013-10-01    28.015079
# 2013-11-01    28.302278
# 2013-12-01    27.190336
# 2014-01-01    25.686511
# 2014-02-01    25.221628
# 2014-03-01    26.208878
# 2014-04-01    27.624618
# 2014-05-01    28.028477
# 2014-06-01    27.000721
# 2014-07-01    25.558737
# 2014-08-01    25.136779
# 2014-09-01    26.150285
# 2014-10-01    27.580623
# Freq: MS, Name: Forward Predictions, dtype: float64

# %%
predictions
# Out:
# 2013-10-01    28.015079
# 2013-11-01    28.302278
# 2013-12-01    27.190336
# 2014-01-01    25.686511
# 2014-02-01    25.221628
# 2014-03-01    26.208878
# 2014-04-01    27.624618
# 2014-05-01    28.028477
# 2014-06-01    27.000721
# 2014-07-01    25.558737
# 2014-08-01    25.136779
# 2014-09-01    26.150285
# 2014-10-01    27.580623
# Freq: MS, Name: Forward Predictions, dtype: float64

# %%
predictions.plot(figsize=(22,5),legend=True)
# Out:
# <AxesSubplot:>

# %%
predictions.plot(figsize=(22,5),legend=True)
# Out:
# <AxesSubplot:>

# %%
import pickle

# %%
pickle_out = open("model","wb")
pickle.dump(results_MA, pickle_out)
pickle_out.close()
